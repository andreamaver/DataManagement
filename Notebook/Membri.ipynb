# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Data_man_Project/Data_Man_project/Data/MEMBRI_GRUPPI_FINAL.csv', sep=';')

# %%
df.head(2)
# Out:
#                                               membri               id_artist
# 0  Stefano Belisari, Sergio Conforti, Davide Civa...  61r4cE4aoOD50wPNhQ5fF7
# 1                                    Kekko Silvestre  3ALm6zJLaJMWV0r89kuYtu

# %%
df.membri = df.membri.apply(lambda x: str.lower(x))

# %%
df.membri = df.membri.apply(lambda x: x.split(', '))
df = df.explode('membri').reset_index(drop=True)

# %%
df.head(5)
# Out:
#              membri               id_artist
# 0  stefano belisari  61r4cE4aoOD50wPNhQ5fF7
# 1   sergio conforti  61r4cE4aoOD50wPNhQ5fF7
# 2   davide civaschi  61r4cE4aoOD50wPNhQ5fF7
# 3     nicola fasani  61r4cE4aoOD50wPNhQ5fF7
# 4   kekko silvestre  3ALm6zJLaJMWV0r89kuYtu

# %%
df[df['membri']=='damiano david']
# Out:
#            membri               id_artist
# 40  damiano david  0lAWpj5szCSwM4rUMHYmrr

# %%
df.to_csv('/content/drive/MyDrive/Data_man_Project/Data_Man_project/Data/membri_final.csv', index=False)
